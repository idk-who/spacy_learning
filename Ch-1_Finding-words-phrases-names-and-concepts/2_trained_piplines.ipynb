# %% [markdown]
# ![](pasted_images/2025-03-25-11-58-49.png)

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB 52.4 kB/s eta 0:04:04
#      ---------------------------------------- 0.0/12.8 MB 52.4 kB/s eta 0:04:04
#      ---------------------------------------- 0.0/12.8 MB 52.4 kB/s eta 0:04:04
#      ---------------------------------------- 0.0/12.8 MB 52.4 kB/s eta 0:04:04
# ...

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("She ate the pizza")

for token in doc:
    print(token.text, token.pos_)
# Out:
# She PRON
# ate VERB
# the DET
# pizza NOUN

# %%
for tk in doc:
    print(f"{tk.text: <10} {tk.pos_: <10} {tk.dep_: <10} {tk.head.text}")
# Out:
# She        PRON       nsubj      ate
# ate        VERB       ROOT       ate
# the        DET        det        pizza
# pizza      NOUN       dobj       ate

# %% [markdown]
# ![](pasted_images/2025-03-25-12-26-10.png)

# %% [markdown]
# ![](pasted_images/2025-03-25-12-33-29.png)

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for ent in doc.ents:
    print(f"{ent.text: <15} {ent.label_}")
# Out:
# Apple           ORG
# U.K.            GPE
# $1 billion      MONEY

# %% [markdown]
# ![](pasted_images/2025-03-25-12-56-45.png)

# %%
print(spacy.explain('GPE'))
print(spacy.explain('NNP'))
print(spacy.explain('dobj'))
# Out:
# Countries, cities, states
# noun, proper singular
# direct object
